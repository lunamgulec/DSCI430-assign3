# %% [markdown]
# # Module 3 - Algorithm auditing: Accuracy, Fairness and Interpretability
#
#
# ### Assignment overview
#
# In this assignment, you will be asked to evaluate a set of trained classifiers for accuracy, fairness and transparency. The classifiers have been trained on the [NIJ Recidivism Challenge Dataset](https://nij.ojp.gov/funding/recidivism-forecasting-challenge) to predict whether or not an individual will be arrested for a new crime within 3 years after being released on parole.
#
# The assignment is modeled after “Accuracy, Fairness, and Interpretability of Machine Learning Criminal Recidivism Models, by Eric Ingram, Furkan Gursoy, Ioannis A. Kakadiaris (https://arxiv.org/abs/2209.14237).
#
# For this assignment, it is possible to work in **groups of up to 2 students**.
#
# ### Group members
# Leave blanks if group has less than 2 members:
# - Student 1:
# - Student 2:
#
#
# ### Learning Goals:
#
# After completing this week's lecture and tutorial work, you will be able to:
# 1. Describe different fairness metrics, such as statistical parity, equal opportunity and equal accuracy
# 2. Discuss fairness and fairness metrics from the perspective of multiple stakeholders
# 3. Define objective functions based on fairness metrics
# 4. Evaluate a model’s transparency using strategies such as global surrogate models, permutation feature importance, and Shapley Additive Explanations (SHAP)
# 5. Evaluate common machine learning models based on their accuracy, fairness and interpretability
# 6. Describe how metrics such as accuracy and fairness need to be balanced for a trained model to have acceptable accuracy and low bias

# %%
pip install aif360[AdversarialDebiasing]
# Out:
# Requirement already satisfied: aif360[AdversarialDebiasing] in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[AdversarialDebiasing]) (1.23.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[AdversarialDebiasing]) (1.13.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[AdversarialDebiasing]) (2.3.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[AdversarialDebiasing]) (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[AdversarialDebiasing]) (3.10.8)
# Requirement already satisfied: tensorflow>=1.13.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[AdversarialDebiasing]) (2.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[AdversarialDebiasing]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[AdversarialDebiasing]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[AdversarialDebiasing]) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->aif360[AdversarialDebiasing]) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.0->aif360[AdversarialDebiasing]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.0->aif360[AdversarialDebiasing]) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.4.0)
# Requirement already satisfied: packaging in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (80.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.12.1)
# Collecting numpy>=1.16 (from aif360[AdversarialDebiasing])
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorboard~=2.20.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.10.1)
# Requirement already satisfied: pillow in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorboard~=2.20.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorboard~=2.20.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tensorboard~=2.20.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.45.1)
# Requirement already satisfied: rich in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from keras>=3.10.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (14.3.1)
# Requirement already satisfied: namex in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from keras>=3.10.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.1.0)
# Requirement already satisfied: optree in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from keras>=3.10.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[AdversarialDebiasing]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[AdversarialDebiasing]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[AdversarialDebiasing]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[AdversarialDebiasing]) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[AdversarialDebiasing]) (3.0.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from rich->keras>=3.10.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from rich->keras>=3.10.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.1.2)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# pycanon 1.1.0 requires numpy==2.0.2, but you have numpy 2.2.6 which is incompatible.
# ydata-profiling 0.0.dev0 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.8 which is incompatible.

# %%
pip install eli5
# Out:
# Requirement already satisfied: eli5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (0.16.0)
# Requirement already satisfied: attrs>17.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (25.4.0)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (3.1.6)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (2.2.6)
# Requirement already satisfied: scipy in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (1.7.2)
# Requirement already satisfied: graphviz in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (0.21)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from eli5) (0.8.10)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from jinja2>=3.0.0->eli5) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.6.0->eli5) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.6.0->eli5) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install aif360[Reductions]
# Out:
# Requirement already satisfied: aif360[Reductions] in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[Reductions]) (2.2.6)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[Reductions]) (1.13.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[Reductions]) (2.3.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[Reductions]) (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[Reductions]) (3.10.8)
# Requirement already satisfied: fairlearn~=0.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[Reductions]) (0.13.0)
# Requirement already satisfied: narwhals>=1.14.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from fairlearn~=0.7->aif360[Reductions]) (2.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[Reductions]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[Reductions]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[Reductions]) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->aif360[Reductions]) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.0->aif360[Reductions]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.0->aif360[Reductions]) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[Reductions]) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install aif360[inFairness]
# Out:
# Requirement already satisfied: aif360[inFairness] in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (2.2.6)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (1.13.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (2.3.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (3.10.8)
# Requirement already satisfied: skorch in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (1.3.1)
# Requirement already satisfied: inFairness>=0.2.2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from aif360[inFairness]) (0.2.3)
# Requirement already satisfied: POT>=0.8.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from inFairness>=0.2.2->aif360[inFairness]) (0.9.6.post1)
# Requirement already satisfied: torch>=1.13.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from inFairness>=0.2.2->aif360[inFairness]) (2.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[inFairness]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[inFairness]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas>=0.24.0->aif360[inFairness]) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->aif360[inFairness]) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.0->aif360[inFairness]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn>=1.0->aif360[inFairness]) (3.6.0)
# Requirement already satisfied: filelock in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (3.4)
# Requirement already satisfied: jinja2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from sympy>=1.13.3->torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from jinja2->torch>=1.13.0->inFairness>=0.2.2->aif360[inFairness]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from matplotlib->aif360[inFairness]) (3.0.9)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from skorch->aif360[inFairness]) (0.8.10)
# Requirement already satisfied: tqdm>=4.14.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from skorch->aif360[inFairness]) (4.67.1)
# Requirement already satisfied: colorama in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tqdm>=4.14.0->skorch->aif360[inFairness]) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Libraries:

# %%
# May require installation of additional libraries like aif360 and eli5

import pandas as pd
import numpy as np
import joblib

# Fairness metrics
from aif360.metrics import BinaryLabelDatasetMetric
from aif360.metrics import ClassificationMetric

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    f1_score,
    make_scorer,
    ConfusionMatrixDisplay,
    accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix
)

import matplotlib.pyplot as plt
import eli5
from sklearn.inspection import permutation_importance
# Out:
# c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\inFairness\utils\ndcg.py:37: FutureWarning: We've integrated functorch into PyTorch. As the final step of the integration, `functorch.vmap` is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use `torch.vmap` instead; see the PyTorch 2.0 release notes and/or the `torch.func` migration guide for more details https://pytorch.org/docs/main/func.migrating.html
#   vect_normalized_discounted_cumulative_gain = vmap(
# c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\inFairness\utils\ndcg.py:48: FutureWarning: We've integrated functorch into PyTorch. As the final step of the integration, `functorch.vmap` is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use `torch.vmap` instead; see the PyTorch 2.0 release notes and/or the `torch.func` migration guide for more details https://pytorch.org/docs/main/func.migrating.html
#   monte_carlo_vect_ndcg = vmap(vect_normalized_discounted_cumulative_gain, in_dims=(0,))

# %% [markdown]
# # Part 1: Getting started:
#
# Before starting this assignment, we ask you to read the paper it has been modeled after, to get an idea of the problem we are working on: https://arxiv.org/abs/2209.14237
#
# You can also review the original dataset source [here](https://nij.ojp.gov/funding/recidivism-forecasting-challenge). The website includes a lot of information on the dataset and a detailed description of each of its columns (look for Appendix 2: Codebook).
#
# Now that you have familiarized with the problem, you know that the goal is predicting the binary variable `Recidivism_Within_3years`, which indicates whether or not the person has committed a new felony or misdemeanour within 3 years from the beginning of parole supervision.
#
# The National Institute of Justice’s (NIJ) obviously would want to deploy a highly accurate predictive model, to make sure that only deserving people get released on parole. Unfortunately, the existence of bias in the training set (typically historical or representation bias) makes it very likely to end up with an unfair classifier, that is, a classifier that produces different results for different protected classes of population.
#
# Your job is to evaluate 4 classifiers, pre-trained and provided to you. This is called **algorithm auditing:** you are not the designer of the model, but you are in charge of evaluating its performance. Algorithm auditing can focus on various metrics and populations of interest, but in this case we will focus on evaluating **accuracy, fairness and transparency** of each algorithm.
#
# To begin, load the dataset and classifiers by running the cells below:

# %%
train_df = pd.read_csv("data/training_set.csv")
test_df = pd.read_csv("data/testing_set.csv")

# %%
test_df.head()
# Out:
#    Unnamed: 0     ID Gender   Race Age_at_Release  Residence_PUMA  \
# 0        3735   3848      M  BLACK    48 or older               1
# 1        5039   5174      M  BLACK    48 or older              20
# 2       16027  16485      F  WHITE          33-37              10
# 3       18863  19486      F  WHITE          43-47              11
# 4       14013  14408      M  WHITE          33-37              14
#
#   Gang_Affiliated  Supervision_Risk_Score_First Supervision_Level_First  \
# 0              No                           6.0                Standard
# 1              No                           2.0             Specialized
# 2             NaN                           6.0                    High
# 3             NaN                           5.0                Standard
# 4              No                           4.0                Standard
#
#        Education_Level  ... DrugTests_Meth_Positive DrugTests_Other_Positive  \
# 0  High School Diploma  ...                     0.0                      0.0
# 1  High School Diploma  ...                     0.0                      0.0
# 2  High School Diploma  ...                     0.0                      0.0
# 3  High School Diploma  ...                     0.0                      0.0
# 4  High School Diploma  ...                     0.0                      0.0
#
#   Percent_Days_Employed Jobs_Per_Year Employment_Exempt  \
# 0               1.00000      0.299385                No
# 1               1.00000      1.544397                No
# 2               0.51049      1.277098                No
# 3               1.00000      1.006198                No
# 4               1.00000      1.318592                No
#
#   Recidivism_Within_3years Recidivism_Arrest_Year1 Recidivism_Arrest_Year2  \
# 0                       No                      No                      No
# 1                      Yes                      No                      No
# 2                       No                      No                      No
# 3                       No                      No                      No
# 4                       No                      No                      No
#
#   Recidivism_Arrest_Year3 Training_Sample
# 0                      No               0
# 1                     Yes               1
# 2                      No               1
# 3                      No               1
# 4                      No               1
#
# [5 rows x 55 columns]

# %%
# Separating features and target
X_train, y_train = (
    train_df.drop(columns=["Recidivism_Within_3years"]),
    train_df["Recidivism_Within_3years"],
)
X_test, y_test = (
    test_df.drop(columns=["Recidivism_Within_3years"]),
    test_df["Recidivism_Within_3years"],
)

# %%
# Loading classifiers
logreg_model  = joblib.load("models_for_A3/NIJ_logreg.joblib")
rf_model      = joblib.load("models_for_A3/NIJ_rf.joblib")
tree_model    = joblib.load("models_for_A3/NIJ_tree.joblib")
xgboost_model = joblib.load("models_for_A3/NIJ_xgboost.joblib")
# Out:
# c:\Users\athen\anaconda3\envs\dsci430\lib\pickle.py:1718: UserWarning: [23:05:43] WARNING: D:\bld\xgboost-split_1765326876395\work\src\gbm\../common/error_msg.h:83: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)

# %% [markdown]
# # Part 2: Classifiers' Accuracy (and other performance metrics):
#
# First, we will evaluate each classifier's accuracy, together with other performance metrics that help us understanding how reliable the classifier's answers are. In addition to accuracy, we will use, **precision, recall and F1 score.**
#
# ### Question 1
#
# Can you provide definition and formula for accuracy, precision, recall and F1 score, as a function of True Positives (TP), True Negatives (TN), False Positives (FP) and False Negatives (FN)?
#
# It may help you use this table for reference:
#
# <img src="ConfMatrix.png" alt="drawing" width="500"/>
#
# Here, we are giving you the definition of AUC, as a reminder and example (note that the other metrics will need the formula):
#
# **AUC:** AUC stands for Area Under the ROC curve. The ROC (receiver operating characteristic) curve is a plot of the recall and false positive rate of a classifier for different classification thresholds (see [here](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc) for more details). AUC values go between 0 and 1. Higher values are more desirable as they indicate that the classifier is good at avoiding both false positives and false negatives. A value of 0.5 for a binary classification indicates that the classifier is no better at predicting the outcome than random guessing.
#
# **Add remaining definitions and formulas here**
#
# | Metric | Formula |
# | ------ | ------- |
# | Accuracy | (TP + TN) / (TP + TN + FP + FN) |
# | Precision | TP / (TP + FP) |
# | Recall | TP / (TP + FN) |
# | F1 Score | 2 × (Precision × Recall) / (Precision + Recall) |
#
#
# ### Question 2
#
# For every classifier given, calculate and report accuracy, precision, recall and F1 score on the test set. For ease of visualization and comparison, we will summarize these results in this dictionary:

# %%
results_dict = {}

# %% [markdown]
# There are different options available to us to compute fairness metrics, such as the many functions included in sklearn. For this exercise, however, we will focus on working with the [aif360](https://aif360.readthedocs.io/en/stable/Getting%20Started.html) library, an open source library designed specifically to examine and mitigate discrimination and bias in machine learning models.
#
# Let's see in an example how we can use aif360 to compute standard performance metrics. We will start with the Random Forest model.

# %%
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# When using aif360, the target has to be numerical, so we will start by converting our target column. Since we are 
# only interested in the metrics from the test set, we will convert only the test target

# Define your mapping
label_map = {"No": 0, "Yes": 1}

# Convert y_test
y_test_num = y_test.map(label_map)

# Since aif360 focuses on fairness, it needs us to identify the protected attribute we will use to segment the population.
protected_attr = 'pipeline-2__Race_WHITE'   

# aif360 can not handle Nans - we must impute before converting. For this purpose, I can use the transformer included in 
# the RF model
X_test_array = rf_model.named_steps['ct'].transform(X_test)

feature_names = rf_model.named_steps['ct'].get_feature_names_out()

X_test_transformed = pd.DataFrame(X_test_array, columns=feature_names, index=X_test.index)

# Locate protected attribute column in transformed test set.
protected_idx = X_test_transformed.columns.get_loc(protected_attr)

# Now that we have collected all this information, we can create a BinaryLabelDataset,
# aif360 base class for all structured datasets with binary labels - like ours!
# https://aif360.readthedocs.io/en/stable/modules/generated/aif360.datasets.BinaryLabelDataset.html#aif360.datasets.BinaryLabelDataset

aif_test = BinaryLabelDataset(
    favorable_label=1, # Being identified as not having committed a crime is the favorable outcome
    unfavorable_label=0,
    df=pd.concat([X_test_transformed, y_test_num], axis=1),
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# %%
# Now, we need to do a similar process and create a BinaryLabelDataset for the predictions of the Random Forest model

# First, we'll get the predictions and convert them to 0 and 1
y_pred = rf_model.predict(X_test)
y_pred_num = pd.Series(y_pred, index=y_test.index).map(label_map)

# Then, we will create a copy of the transformed test feature matrix and attach the predictions to it
pred_df = X_test_transformed.copy()
pred_df[y_test.name] = y_pred_num

# Finally, we piece everything together in a BinaryLabelDataset 
aif_pred = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pred_df,
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# %%
# We are now ready to compute some metrics using aif_test (our ground truth) and aif_pred (our predictions)
classified_metric_rf = ClassificationMetric(
    aif_test,
    aif_pred,
    unprivileged_groups=[{protected_attr: 0}],
    privileged_groups=[{protected_attr: 1}]
)

precision = classified_metric_rf.precision()
recall = classified_metric_rf.recall()

# aif360 does not have a function foro F1 - we will compute F1 manually
if (precision + recall) > 0:
    f1 = 2 * (precision * recall) / (precision + recall)
else:
    f1 = 0.0

# Saving results in the dictionary
results_dict["RandomForest"] = {
    "accuracy": format(classified_metric_rf.accuracy(), ".3f"),
    "precision": format(precision, ".3f"),
    "recall": format(recall, ".3f"),
    "f1_score": format(f1, ".3f"),
}

# %%
# We can check our results
pd.DataFrame(results_dict)
# Out:
#           RandomForest
# accuracy         0.720
# precision        0.740
# recall           0.788
# f1_score         0.763

# %% [markdown]
# Repeat the steps above for the logistic regression, decision tree, and xgboost model, and add the results to the dictionary.

# %%
# Check the structure of each model
print("Logistic Regression steps:")
print(logreg_model.named_steps.keys())
print()

print("Random Forest steps:")
print(rf_model.named_steps.keys())
print()

print("Decision Tree steps:")
print(tree_model.named_steps.keys())
print()

print("XGBoost steps:")
print(xgboost_model.named_steps.keys())
# Out:
# Logistic Regression steps:
# dict_keys(['columntransformer', 'logisticregression'])
#
# Random Forest steps:
# dict_keys(['ct', 'rf'])
#
# Decision Tree steps:
# dict_keys(['ct', 'dt'])
#
# XGBoost steps:
# dict_keys(['ct', 'XGB'])

# %% [markdown]
# ### LogReg Model:

# %%
# Transform test data using LogReg model
X_test_array_lr = logreg_model.named_steps['columntransformer'].transform(X_test)
feature_names_lr = logreg_model.named_steps['columntransformer'].get_feature_names_out()
X_test_transformed_lr = pd.DataFrame(X_test_array_lr, columns=feature_names_lr, index=X_test.index)

# Create ground truth dataset (reuse protected_attr, same for all)
aif_test_lr = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pd.concat([X_test_transformed_lr, y_test_num], axis=1),
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# Get predictions
y_pred_lr = logreg_model.predict(X_test)
y_pred_num_lr = pd.Series(y_pred_lr, index=y_test.index).map(label_map)

# Create predictions dataset
pred_df_lr = X_test_transformed_lr.copy()
pred_df_lr[y_test.name] = y_pred_num_lr

aif_pred_lr = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pred_df_lr,
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# Calculate metrics
classified_metric_lr = ClassificationMetric(
    aif_test_lr,
    aif_pred_lr,
    unprivileged_groups=[{protected_attr: 0}],
    privileged_groups=[{protected_attr: 1}]
)

precision_lr = classified_metric_lr.precision()
recall_lr = classified_metric_lr.recall()

if (precision_lr + recall_lr) > 0:
    f1_lr = 2 * (precision_lr * recall_lr) / (precision_lr + recall_lr)
else:
    f1_lr = 0.0

# Store results
results_dict["LogisticRegression"] = {
    "accuracy": format(classified_metric_lr.accuracy(), ".3f"),
    "precision": format(precision_lr, ".3f"),
    "recall": format(recall_lr, ".3f"),
    "f1_score": format(f1_lr, ".3f"),
}

# %% [markdown]
# ### Decision Tree Model:

# %%
# Transform test data using Decision Tree model
X_test_array_dt = tree_model.named_steps['ct'].transform(X_test)
feature_names_dt = tree_model.named_steps['ct'].get_feature_names_out()
X_test_transformed_dt = pd.DataFrame(X_test_array_dt, columns=feature_names_dt, index=X_test.index)

# Create ground truth dataset
aif_test_dt = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pd.concat([X_test_transformed_dt, y_test_num], axis=1),
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# Get predictions
y_pred_dt = tree_model.predict(X_test)
y_pred_num_dt = pd.Series(y_pred_dt, index=y_test.index).map(label_map)

# Create predictions dataset
pred_df_dt = X_test_transformed_dt.copy()
pred_df_dt[y_test.name] = y_pred_num_dt

aif_pred_dt = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pred_df_dt,
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# Calculate metrics
classified_metric_dt = ClassificationMetric(
    aif_test_dt,
    aif_pred_dt,
    unprivileged_groups=[{protected_attr: 0}],
    privileged_groups=[{protected_attr: 1}]
)

precision_dt = classified_metric_dt.precision()
recall_dt = classified_metric_dt.recall()

if (precision_dt + recall_dt) > 0:
    f1_dt = 2 * (precision_dt * recall_dt) / (precision_dt + recall_dt)
else:
    f1_dt = 0.0

# Store results
results_dict["DecisionTree"] = {
    "accuracy": format(classified_metric_dt.accuracy(), ".3f"),
    "precision": format(precision_dt, ".3f"),
    "recall": format(recall_dt, ".3f"),
    "f1_score": format(f1_dt, ".3f"),
}

# %% [markdown]
# ### XGBoost Model:

# %%
# Transform test data using XGBoost model
X_test_array_xgb = xgboost_model.named_steps['ct'].transform(X_test)
feature_names_xgb = xgboost_model.named_steps['ct'].get_feature_names_out()
X_test_transformed_xgb = pd.DataFrame(X_test_array_xgb, columns=feature_names_xgb, index=X_test.index)

# Create ground truth dataset
aif_test_xgb = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pd.concat([X_test_transformed_xgb, y_test_num], axis=1),
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# Get predictions
y_pred_xgb_raw = xgboost_model.predict(X_test)

# Check if predictions are already numeric or strings
if isinstance(y_pred_xgb_raw[0], (int, np.integer, float, np.floating)):
    # Already numeric - convert to int just to be safe
    y_pred_num_xgb = pd.Series(y_pred_xgb_raw.astype(int), index=y_test.index)
else:
    # String predictions - map them
    y_pred_num_xgb = pd.Series(y_pred_xgb_raw, index=y_test.index).map(label_map)

print(f"XGBoost prediction check:")
print(f"Unique values: {y_pred_num_xgb.unique()}")
print(f"Value counts:\n{y_pred_num_xgb.value_counts()}")

# Create predictions dataset
pred_df_xgb = X_test_transformed_xgb.copy()
pred_df_xgb[y_test.name] = y_pred_num_xgb

# Handle NAs if present
if pred_df_xgb.isna().any().any():
    pred_df_xgb = pred_df_xgb.fillna(0)

aif_pred_xgb = BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=pred_df_xgb,
    label_names=[y_test.name],
    protected_attribute_names=[protected_attr]
)

# Calculate metrics
classified_metric_xgb = ClassificationMetric(
    aif_test_xgb,
    aif_pred_xgb,
    unprivileged_groups=[{protected_attr: 0}],
    privileged_groups=[{protected_attr: 1}]
)

precision_xgb = classified_metric_xgb.precision()
recall_xgb = classified_metric_xgb.recall()

if (precision_xgb + recall_xgb) > 0:
    f1_xgb = 2 * (precision_xgb * recall_xgb) / (precision_xgb + recall_xgb)
else:
    f1_xgb = 0.0

# Store results
results_dict["XGBoost"] = {
    "accuracy": format(classified_metric_xgb.accuracy(), ".3f"),
    "precision": format(precision_xgb, ".3f"),
    "recall": format(recall_xgb, ".3f"),
    "f1_score": format(f1_xgb, ".3f"),
}

print("\nXGBoost Results:")
print(results_dict["XGBoost"])
# Out:
# XGBoost prediction check:
# Unique values: [0 1]
# Value counts:
# 1    4965
# 0    2786
# Name: count, dtype: int64
#
# XGBoost Results:
# {'accuracy': '0.741', 'precision': '0.745', 'recall': '0.833', 'f1_score': '0.787'}

# %%
# We can check our results
pd.DataFrame(results_dict)
# Out:
#           RandomForest LogisticRegression DecisionTree XGBoost
# accuracy         0.720              0.709        0.707   0.741
# precision        0.740              0.767        0.699   0.745
# recall           0.788              0.708        0.858   0.833
# f1_score         0.763              0.736        0.771   0.787

# %% [markdown]
# ### Question 3
#
# For every classifier given, plot the confusion matrices on training and test set. Here is another function you will find helpful for this task: [`confusion_matrix`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html).

# %% [markdown]
# #### Confusion Matrix - logistic regression:

# %%
# Use confusion_matrix to plot your result here
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_pred_lr = logreg_model.predict(X_test)

# Create confusion matrix
cm_lr = confusion_matrix(y_test, y_pred_lr, labels=["No", "Yes"])

# Plot it
disp_lr = ConfusionMatrixDisplay(confusion_matrix=cm_lr, display_labels=["No", "Yes"])
disp_lr.plot(cmap='Blues')
plt.title('Logistic Regression - Confusion Matrix')
plt.show()

# Sanity check with AIF360
print("AIF360 confusion matrix for comparison:")
print(classified_metric_lr.binary_confusion_matrix(privileged=None))
# Out:
# AIF360 confusion matrix for comparison:
# {'TP': np.float64(3145.0), 'FP': np.float64(958.0), 'TN': np.float64(2352.0), 'FN': np.float64(1296.0)}

# %%
# As a sanity check, it is a good idea to compare these results with the ones we would get using aif360
# If they don't match, something went wrong
classified_metric_lr.binary_confusion_matrix(privileged=None)
# Out:
# {'TP': np.float64(3145.0),
#  'FP': np.float64(958.0),
#  'TN': np.float64(2352.0),
#  'FN': np.float64(1296.0)}

# %% [markdown]
# #### Confusion Matrix - random forest:

# %%
# Use confusion_matrix to plot your result here
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_pred_rf = rf_model.predict(X_test)

# Create confusion matrix
cm_rf = confusion_matrix(y_test, y_pred_rf, labels=["No", "Yes"])

# Plot it
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf, display_labels=["No", "Yes"])
disp_rf.plot(cmap='Blues')
plt.title('Random Forest - Confusion Matrix')
plt.show()

# Sanity check with AIF360
print("AIF360 confusion matrix for comparison:")
print(classified_metric_rf.binary_confusion_matrix(privileged=None))
# Out:
# AIF360 confusion matrix for comparison:
# {'TP': np.float64(3499.0), 'FP': np.float64(1228.0), 'TN': np.float64(2082.0), 'FN': np.float64(942.0)}

# %%
classified_metric_rf.binary_confusion_matrix(privileged=None)
# Out:
# {'TP': np.float64(3499.0),
#  'FP': np.float64(1228.0),
#  'TN': np.float64(2082.0),
#  'FN': np.float64(942.0)}

# %% [markdown]
# #### Confusion Matrix - decision tree:

# %%
# Use confusion_matrix to plot your result here
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_pred_dt = tree_model.predict(X_test)

# Create confusion matrix
cm_dt = confusion_matrix(y_test, y_pred_dt, labels=["No", "Yes"])

# Plot it
disp_dt = ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=["No", "Yes"])
disp_dt.plot(cmap='Blues')
plt.title('Decision Tree - Confusion Matrix')
plt.show()

# Sanity check with AIF360
print("AIF360 confusion matrix for comparison:")
print(classified_metric_dt.binary_confusion_matrix(privileged=None))
# Out:
# AIF360 confusion matrix for comparison:
# {'TP': np.float64(3811.0), 'FP': np.float64(1639.0), 'TN': np.float64(1671.0), 'FN': np.float64(630.0)}

# %%
classified_metric_dt.binary_confusion_matrix(privileged=None)
# Out:
# {'TP': np.float64(3811.0),
#  'FP': np.float64(1639.0),
#  'TN': np.float64(1671.0),
#  'FN': np.float64(630.0)}

# %% [markdown]
# #### Confusion Matrix XGBoost:

# %%
# Use confusion_matrix to plot your result here
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get predictions (these are numeric: 0, 1)
y_pred_xgb_numeric = xgboost_model.predict(X_test)

# Convert numeric predictions back to strings to match y_test
reverse_label_map = {0: "No", 1: "Yes"}
y_pred_xgb_strings = pd.Series(y_pred_xgb_numeric.astype(int)).map(reverse_label_map)

# Create confusion matrix
cm_xgb = confusion_matrix(y_test, y_pred_xgb_strings, labels=["No", "Yes"])

# Plot it
disp_xgb = ConfusionMatrixDisplay(confusion_matrix=cm_xgb, display_labels=["No", "Yes"])
disp_xgb.plot(cmap='Blues')
plt.title('XGBoost - Confusion Matrix')
plt.show()

# Sanity check with AIF360
print("AIF360 confusion matrix for comparison:")
print(classified_metric_xgb.binary_confusion_matrix(privileged=None))
# Out:
# AIF360 confusion matrix for comparison:
# {'TP': np.float64(3700.0), 'FP': np.float64(1265.0), 'TN': np.float64(2045.0), 'FN': np.float64(741.0)}

# %%
classified_metric_xgb.binary_confusion_matrix(privileged=None)
# Out:
# {'TP': np.float64(3700.0),
#  'FP': np.float64(1265.0),
#  'TN': np.float64(2045.0),
#  'FN': np.float64(741.0)}

# %% [markdown]
# ### Question 4
#
# Based on the results obtained so far, answer the following questions, providing an explanation and trying to base your decision on multiple metrics:
# - Which classifiers would you choose for deployment?
# - Which classifier is the most "severe" (a.k.a. classifies more people as at risk of committing another crime within 3 years)?
# - Which classifier is the most cautious (a.k.a. classifies less people as at risk of committing another crime within 3 years)?

# %% [markdown]
# **Your answer here**
# - I would choose XGBoost for deployment because it has the best overall performance with the highest F1 score (0.787) and accuracy (0.741). This means it provides a good balance between catching actual recidivists (recall) and not falsely labeling people (precision). In a criminal justice context, having this balance is important because we want to protect public safety without unfairly denying parole to people who won't reoffend. XGBoost outperforms the other models in finding this middle ground.
# - The Decision Tree is the most severe classifier, predicting recidivism for 70.3% of cases (5,450 out of 7,751 people). This makes sense given its very high recall (0.858). It's aggressive about flagging potential recidivists, which means it catches more actual offenders but also creates more false positives. This could lead to more people being unfairly denied parole.
# - The Logistic Regression model is the most cautious, only predicting recidivism for 52.9% of cases (4,103 people). This aligns with its high precision (0.767) and lower recall (0.708). While it makes fewer mistakes when it does predict recidivism, it also misses more actual recidivists compared to the other models. This more conservative approach might be preferred if we want to avoid wrongly denying people parole.

# %%
# Calculate severity (how many predicted "Yes")
print("Number of 'Yes' predictions (severity) by model:\n")

for model_name, y_pred in [
    ("Logistic Regression", y_pred_lr),
    ("Random Forest", y_pred_rf),
    ("Decision Tree", y_pred_dt),
    ("XGBoost", pd.Series(y_pred_xgb_numeric).map({0: "No", 1: "Yes"}))
]:
    yes_count = (y_pred == "Yes").sum()
    yes_percentage = (yes_count / len(y_pred)) * 100
    print(f"{model_name}: {yes_count} ({yes_percentage:.1f}%)")
# Out:
# Number of 'Yes' predictions (severity) by model:
#
# Logistic Regression: 4103 (52.9%)
# Random Forest: 4727 (61.0%)
# Decision Tree: 5450 (70.3%)
# XGBoost: 4965 (64.1%)

# %% [markdown]
# # Part 3 :  Fairness Evaluation:

# %% [markdown]
# Now that we have an understanding of how accurate our classifiers are across all samples, we need to measure their *fairness* across different categories. In similar problems, we are typically concerned with the classifiers being fair across different segments of protected populations (e.g. different genders or ethnicities). The original paper evaluates fairness for both gender and race, but for the purpose of this exercise we will only look at fairness across race, that is, for white and Black defendants.
#
# ### Question 5
#
# As we have seen in class, there is not just one fairness metric, but several, as they have different ways to identify different treatments across populations. The metrics used in the paper are:
#
# 1. *Predicted Positive Rate Disparity (PPRD)*, whether the numbers of positive predictions are on par across groups.
# 2. *Predicted Positive Group Rate Disparity (PPGRD)*, whether the rates of positive predictions are on par across groups.
# 3. *False Discovery Rate Disparity (FDRD)*, whether the ratios of false positives to predicted positives are on par across groups.
# 4. *False Positive Rate Disparity (FPRD)*, whether the ratios of false positives to actual negatives are on par across groups.
# 5. *False Omission Rate Disparity (FORD)*, whether the ratios of false negatives to predicted negatives are on par across groups.
# 6. *False Negative Rate Disparity (FNRD)*, whether the ratios of false negatives to actual positives are on par across groups.
#
# Before jumping into code writing, we must make sure that we have a solid understanding of how these metrics are computed from the True Positive, True Negative, False Positive, and False Negative values *for each group*. We will add the subscript *b* and *w* when appropriate to identify metrics from the group of black or white defendants, respectively. Then, we will write the equations for all fairness metrics. The first one is provided to you as an example:
#
# | Metric    | Formula |
# | :-------- | :------- |
# | PPRD  |  (TPb + FPb) / (TPw + FPw)  |
# | PPGRD | [(TPb + FPb) / (TPb + FPb + TNb + FNb)] / [(TPw + FPw) / (TPw + FPw + TNw + FNw)]  |
# | FDRD | [FPb / (TPb + FPb)] / [FPw / (TPw + FPw)]  |
# | FPRD | [FPb / (FPb + TNb)] / [FPw / (FPw + TNw)]  |
# | FORD | [FNb / (FNb + TNb)] / [FNw / (FNw + TNw)]  |
# | FNRD | [FNb / (FNb + TPb)] / [FNw / (TPw + FNw)]  |

# %% [markdown]
# ## Question 6
#
# Now that we have our formulas, let's test them by manually calculating some fairness metrics based on these two hypothetical confusion matrices:
#
# | Confusion Matrix Group A | | | Confusion Matrix Group B |  | |
# |--------------------|--|--|--------------------|--|--|
# |        | Pred 1 | Pred 0 |        | Pred 1 | Pred 0 |
# | **Actual 1** | 55 | 5 | **Actual 1** | 30 | 30 |
# | **Actual 0** | 30 | 410 | **Actual 0** | 20 | 420 |
#
# Helping yourself with the table from Question 5, compute the PPGDR, FPRD and FNRD for this scenario, using Group A as the reference (denominator). If we assumed that the positive class (1) represents the most desirable outcome, which group is at an advantage? Explain your answer.
#
# PPGRD:
# - Group B rate: (30 + 20) / (30 + 20 + 420 + 30) = 50/500 = 0.10
# - Group A rate: (55 + 30) / (55 + 30 + 410 + 5) = 85/500 = 0.17
# - **PPGRD = 0.10 / 0.17 = 0.588**
#
# FPRD:
# - Group B: FP/(FP+TN) = 20/(20+420) = 20/440 = 0.045
# - Group A: FP/(FP+TN) = 30/(30+410) = 30/440 = 0.068
# - **FPRD = 0.045 / 0.068 = 0.662**
#
# FNRD:
# - Group B: FN/(FN+TP) = 30/(30+30) = 30/60 = 0.50
# - Group A: FN/(FN+TP) = 5/(5+55) = 5/60 = 0.083
# - **FNRD = 0.50 / 0.083 = 6.02**
#
#
# Group A is at an advantage. Group B has:
#
# - Lower positive prediction rate (PPGRD < 1) - less likely to be flagged for the favourable outcome.
# - Much higher false negative rate (FNRD = 6.02) - when they should get the positive outcome, they're 6x more likely to be wrongly denied it.
#
# Since "1" is the favourable outcome, Group B is being disadvantaged - they're less likely to receive the positive classification even when they deserve it.

# %% [markdown]
# ## Question 7
#
# Now we will move to computing a selection of fairness metrics on the 4 estimators we are testing, so that we may test if they are producing fair classifications. We will compute all the metrics, except for PPDR.
#
# Since we will be using the `aif360` library, you will need to read its documentation to figure out which functions will give us the result we are looking for. Check the documentation on the [`ClassificationMetric` class](https://aif360.readthedocs.io/en/latest/modules/generated/aif360.metrics.ClassificationMetric.html#), and complete the table below with the correct methods. The first one is given as an example:
#
# | Metric    | ClassificationMetric method |
# | :-------- | :------- |
# | PPGRD |  `disparate_impact()` |
# | FDRD |   |
# | FPRD |   |
# | FORD |   |
# | FNRD |   |

# %% [markdown]
# ## Question 8
#
# We are finally ready to compute the fairness metrics on our models! Do so for all models, and add the results to `results_dict`, so that we may easily compare them later.
#
# **Hint:** it is highly recommended to repurpose the `ClassificationMetric` objects created in Question 2.

# %% [markdown]
# ### LogReg Model:

# %%
# Calculate fairness metrics for Logistic Regression
results_dict["LogisticRegression"]["PPGRD"] = format(classified_metric_lr.disparate_impact(), ".3f")
results_dict["LogisticRegression"]["FDRD"] = format(classified_metric_lr.false_discovery_rate_ratio(), ".3f")
results_dict["LogisticRegression"]["FPRD"] = format(classified_metric_lr.false_positive_rate_ratio(), ".3f")
results_dict["LogisticRegression"]["FORD"] = format(classified_metric_lr.false_omission_rate_ratio(), ".3f")
results_dict["LogisticRegression"]["FNRD"] = format(classified_metric_lr.false_negative_rate_ratio(), ".3f")

# %% [markdown]
# ### Random Forest Model:

# %%
# Random Forest
results_dict["RandomForest"]["PPGRD"] = format(classified_metric_rf.disparate_impact(), ".3f")
results_dict["RandomForest"]["FDRD"] = format(classified_metric_rf.false_discovery_rate_ratio(), ".3f")
results_dict["RandomForest"]["FPRD"] = format(classified_metric_rf.false_positive_rate_ratio(), ".3f")
results_dict["RandomForest"]["FORD"] = format(classified_metric_rf.false_omission_rate_ratio(), ".3f")
results_dict["RandomForest"]["FNRD"] = format(classified_metric_rf.false_negative_rate_ratio(), ".3f")

# %% [markdown]
# ### Tree Model:

# %%
# Decision Tree  
results_dict["DecisionTree"]["PPGRD"] = format(classified_metric_dt.disparate_impact(), ".3f")
results_dict["DecisionTree"]["FDRD"] = format(classified_metric_dt.false_discovery_rate_ratio(), ".3f")
results_dict["DecisionTree"]["FPRD"] = format(classified_metric_dt.false_positive_rate_ratio(), ".3f")
results_dict["DecisionTree"]["FORD"] = format(classified_metric_dt.false_omission_rate_ratio(), ".3f")
results_dict["DecisionTree"]["FNRD"] = format(classified_metric_dt.false_negative_rate_ratio(), ".3f")

# %% [markdown]
# ### XGBoost Model:

# %%
# XGBoost
results_dict["XGBoost"]["PPGRD"] = format(classified_metric_xgb.disparate_impact(), ".3f")
results_dict["XGBoost"]["FDRD"] = format(classified_metric_xgb.false_discovery_rate_ratio(), ".3f")
results_dict["XGBoost"]["FPRD"] = format(classified_metric_xgb.false_positive_rate_ratio(), ".3f")
results_dict["XGBoost"]["FORD"] = format(classified_metric_xgb.false_omission_rate_ratio(), ".3f")
results_dict["XGBoost"]["FNRD"] = format(classified_metric_xgb.false_negative_rate_ratio(), ".3f")

# %%
# View complete results
pd.DataFrame(results_dict)
# Out:
#           RandomForest LogisticRegression DecisionTree XGBoost
# accuracy         0.720              0.709        0.707   0.741
# precision        0.740              0.767        0.699   0.745
# recall           0.788              0.708        0.858   0.833
# f1_score         0.763              0.736        0.771   0.787
# PPGRD            1.104              1.047        1.058   1.088
# FDRD             1.015              1.040        0.997   1.016
# FPRD             1.189              1.154        1.119   1.172
# FORD             1.014              1.128        1.097   1.023
# FNRD             0.833              1.026        0.919   0.844

# %% [markdown]
# ### Question 9
#
# Based on the results obtained so far, answer the following questions, providing an explanation for each answer:
# - Which model would you say exhibits the least amount of bias? Which one shows the most bias?
#     - The Decision Tree shows the most consistent fairness across metrics. Its PPGRD (1.058) and FPRD (1.119) are closest to 1.0 among all models, and its FDRD (0.997) is almost perfectly fair. While it's not perfect, it treats both racial groups more equally overall compared to the other models.
#     - Random Forest shows the most bias, particularly in PPGRD (1.104) and FPRD (1.189). The FPRD of 1.189 is especially concerning - it means Black defendants who won't recidivate are nearly 19% more likely to be wrongly flagged as risky compared to White defendants. This could lead to unfair denial of parole for innocent Black individuals.
# - Based on the application, which fairness metric(s) do you think should be the most important? Which one(s) could be taken less into consideration?
#     - FPRD (False Positive Rate Disparity) is the most critical metric for this application because it directly measures whether innocent people from different racial groups are being wrongly denied parole at different rates. A high FPRD means we're unfairly punishing people who wouldn't reoffend, which violates their rights and perpetuates systemic bias. Since parole decisions deeply affect people's lives and freedom, minimizing wrongful denials across all groups should be our top priority.
#     - FNRD (False Negative Rate Disparity) While still relevant, FNRD is less critical in this context. All our models show FNRD values below or close to 1.0, meaning they're actually slightly more likely to miss White recidivists than Black recidivists. This is less of a fairness concern compared to wrongly denying parole (FPRD). However, we still need to consider it for public safety.
#
# - Finally, based on the fairness results, which model would you pick for this application? Is your pick different from the one based on performance metrics alone?

# %% [markdown]
# # Part 4: Interpretability Evaluation:
#
# Finally, we will evaluate the *interpretability* of our models. It is important to be able to explain how the model uses each feature to make its predictions and *why* a model has given a particular response for an individual - especially important when, like in this case, people's lives are being affected.

# %% [markdown]
# ### Inherently Interpretable Models
#
# Some models are known to be *inherently interpretable*, meaning we can decifer the model behavior by looking at its parameters. These models are also called "white-box" models. Logistic regression models and decision trees - in some cases - fall in this category.

# %% [markdown]
# ### Question 10
#
# Run the cells below and look at the weights of the logistic regression model. For simplicity, the cells below show the 10 most positive and 10 most negative coefficients. What features bring the prediction more toward the positive class? What other features push the prediction toward the negative class? Do you see any coefficients that may be unfairly influencing the decision?

# %%
feature_names = np.array(logreg_model.named_steps['columntransformer'].get_feature_names_out())
coeffs = logreg_model.named_steps["logisticregression"].coef_.flatten()
coeff_df = pd.DataFrame(coeffs, index=feature_names, columns=["Coefficient"])
coeff_df_sorted = coeff_df.sort_values(by="Coefficient", ascending=False)

# %%
coeff_df_sorted.head(10)
# Out:
#                                                     Coefficient
# pipeline-2__Age_at_Release_18-22                       0.884382
# pipeline-2__Gang_Affiliated_Yes                        0.804385
# pipeline-2__Delinquency_Reports_1                      0.607683
# pipeline-2__Prior_Arrest_Episodes_Felony_10 or ...     0.516977
# pipeline-2__Age_at_Release_23-27                       0.468075
# pipeline-2__Gender_M                                   0.393397
# pipeline-2__Condition_MH_SA_Yes                        0.341486
# pipeline-2__Prior_Revocations_Parole_Yes               0.323501
# pipeline-1__Jobs_Per_Year                              0.313777
# pipeline-2__Violations_ElectronicMonitoring_Yes        0.298216

# %%
coeff_df_sorted.tail(10)
# Out:
#                                                     Coefficient
# pipeline-2__Prison_Years_Greater than 2 to 3 years    -0.278476
# pipeline-2__Prior_Arrest_Episodes_Misd_0              -0.297001
# pipeline-2__Delinquency_Reports_3                     -0.297566
# pipeline-2__Prior_Arrest_Episodes_Felony_2            -0.363059
# pipeline-2__Program_Attendances_10 or more            -0.386280
# pipeline-2__Age_at_Release_43-47                      -0.427602
# pipeline-2__Delinquency_Reports_4 or more             -0.565622
# pipeline-1__Percent_Days_Employed                     -0.664104
# pipeline-2__Prior_Arrest_Episodes_Felony_1            -0.681851
# pipeline-2__Age_at_Release_48 or older                -0.802131

# %% [markdown]
# ### Question 11
#
# Now, let's look at a particular sample and try to explain its prediction. We have picked this sample because its feature values make it a hard case, one very close to the threshold between positive and negative class:

# %%
hard_sample = X_test[5:6]

# %% [markdown]
# If you look at the ground truth for this sample you will see that this person has, in fact, committed a new crime within 3 years from release. But what is the prediction of the logistic regression model? Find the answer below:

# %%
logreg_model.predict(hard_sample)
# Out:
# array(['Yes'], dtype=object)

# %%
# The label for this sample is, in fact, 'Yes'
y_test[5]
# Out:
# 'Yes'

# %% [markdown]
# Take a closer look at the feature values for this sample. What seems to have contributed the most to the final prediction? What feature pushed the most in the opposite direction?

# %% [markdown]
# ### Question 12
# We said that decision trees are also inherently interpretable - *potentially*. That is because, in theory, it is possible to look at the tree structure and to follow the path along the tree to see how each node influenced the decision. But this is only possible if the tree has a reasonably small size.
#
# Run the cell below and see if you can tell what are the most influencial features in the decision tree model.

# %%
from sklearn import tree

tree.plot_tree(tree_model["dt"],fontsize=10)
plt.figure(figsize=(10,6))
plt.show()

# %% [markdown]
# If the method above was not satisfactory, you can try visualizing all the rules of the decision tree as text. Is this any better?

# %%
from sklearn.tree import export_text
tree_rules = export_text(tree_model.named_steps['dt'], feature_names=list(tree_model.named_steps['ct'].get_feature_names_out()))
print(tree_rules)
# Out:
# |--- pipeline-1__Percent_Days_Employed <= -0.00
# |   |--- pipeline-2__Age_at_Release_48 or older <= 0.50
# |   |   |--- pipeline-2__Gang_Affiliated_Yes <= 0.50
# |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_1 <= 0.50
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_6 or more <= 0.50
# |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= 0.19
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= -1.15
# |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 <= 0.50
# |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA <= -0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA >  -0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 >  0.50
# |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.13
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.13
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_Cocaine_Positive <= -0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_Cocaine_Positive >  -0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  -1.15
# |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= -0.25
# |   |   |   |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  -0.25
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  0.19
# |   |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_4 or more <= 0.50
# |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive <= 0.63
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Years_1-2 years <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Years_1-2 years >  0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Drug_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Drug_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive >  0.63
# |   |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= 1.02
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  1.02
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_4 or more >  0.50
# |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive <= 0.79
# |   |   |   |   |   |   |   |   |--- pipeline-2__Education_Level_High School Diploma <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Education_Level_High School Diploma >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive >  0.79
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_6 or more >  0.50
# |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_4 or more <= 0.50
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= -1.13
# |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_3 or more <= 0.50
# |   |   |   |   |   |   |   |   |--- pipeline-2__Age_at_Release_28-32 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Age_at_Release_28-32 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_3 or more >  0.50
# |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA <= 0.09
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive <= -0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive >  -0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA >  0.09
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  -1.13
# |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.16
# |   |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= -0.48
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  -0.48
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.16
# |   |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= -0.93
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  -0.93
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_4 or more >  0.50
# |   |   |   |   |   |   |--- pipeline-2__Education_Level_High School Diploma <= 0.50
# |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA <= 0.09
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA >  0.09
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-2__Education_Level_High School Diploma >  0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_1 >  0.50
# |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= -1.07
# |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive <= -0.17
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive >  -0.17
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  -1.07
# |   |   |   |   |   |--- class: Yes
# |   |   |--- pipeline-2__Gang_Affiliated_Yes >  0.50
# |   |   |   |--- pipeline-2__Delinquency_Reports_4 or more <= 0.50
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 <= 0.50
# |   |   |   |   |   |--- pipeline-1__Residence_PUMA <= -0.40
# |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard <= 0.50
# |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard >  0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-1__Residence_PUMA >  -0.40
# |   |   |   |   |   |   |--- pipeline-2__Dependents_0 <= 0.50
# |   |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Specialized <= 0.50
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Offense_Property <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Offense_Property >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-2__Supervision_Level_First_Specialized >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-2__Dependents_0 >  0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 >  0.50
# |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 <= 0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 >  0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-2__Delinquency_Reports_4 or more >  0.50
# |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 <= 0.50
# |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.17
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.17
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 >  0.50
# |   |   |   |   |   |--- class: Yes
# |   |--- pipeline-2__Age_at_Release_48 or older >  0.50
# |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_10 or more <= 0.50
# |   |   |   |--- pipeline-1__Percent_Days_Employed <= -1.15
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_6 or more <= 0.50
# |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 <= 0.50
# |   |   |   |   |   |   |--- pipeline-2__Condition_MH_SA_Yes <= 0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- pipeline-2__Condition_MH_SA_Yes >  0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 >  0.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_6 or more >  0.50
# |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-1__Percent_Days_Employed >  -1.15
# |   |   |   |   |--- class: Yes
# |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_10 or more >  0.50
# |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_4 or more <= 0.50
# |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard <= 0.50
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-2__Supervision_Level_First_Standard >  0.50
# |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -1.10
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -1.10
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_4 or more >  0.50
# |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive <= -0.38
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive >  -0.38
# |   |   |   |   |   |--- class: Yes
# |--- pipeline-1__Percent_Days_Employed >  -0.00
# |   |--- pipeline-1__Jobs_Per_Year <= 0.01
# |   |   |--- pipeline-1__Percent_Days_Employed <= 0.00
# |   |   |   |--- class: No
# |   |   |--- pipeline-1__Percent_Days_Employed >  0.00
# |   |   |   |--- pipeline-1__Percent_Days_Employed <= 0.39
# |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -0.25
# |   |   |   |   |   |--- class: No
# |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -0.25
# |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_0 <= 0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_0 >  0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-1__Percent_Days_Employed >  0.39
# |   |   |   |   |--- pipeline-1__Jobs_Per_Year <= -0.56
# |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 0.94
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  0.94
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- pipeline-1__Jobs_Per_Year >  -0.56
# |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 1.11
# |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 <= 0.50
# |   |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year <= -0.17
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_10 or more <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Condition_MH_SA_Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Condition_MH_SA_Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_10 or more >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year >  -0.17
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 >  0.50
# |   |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year <= -0.42
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year >  -0.42
# |   |   |   |   |   |   |   |   |--- pipeline-2__Condition_Cog_Ed_Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Condition_Cog_Ed_Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  1.11
# |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year <= -0.26
# |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -0.25
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -0.25
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year >  -0.26
# |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 1.21
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  1.21
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |--- pipeline-1__Jobs_Per_Year >  0.01
# |   |   |--- pipeline-2__Gang_Affiliated_Yes <= 0.50
# |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 <= 0.50
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_10 or more <= 0.50
# |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -0.67
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 1.03
# |   |   |   |   |   |   |   |--- pipeline-2__Race_WHITE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- pipeline-2__Race_WHITE >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  1.03
# |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 <= 0.50
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Property_0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -0.67
# |   |   |   |   |   |   |--- pipeline-1__DrugTests_Meth_Positive <= 0.87
# |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 0.50
# |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA <= -0.54
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA >  -0.54
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  0.50
# |   |   |   |   |   |   |   |   |--- pipeline-2__Gender_M <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- pipeline-2__Residence_Changes_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Gender_M >  0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Residence_PUMA >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-1__DrugTests_Meth_Positive >  0.87
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_10 or more >  0.50
# |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  0.50
# |   |   |   |   |   |   |--- pipeline-1__DrugTests_Meth_Positive <= -0.09
# |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -0.67
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Offense_Property <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Offense_Property >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -0.67
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Years_Less than 1 year <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prison_Years_Less than 1 year >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-1__DrugTests_Meth_Positive >  -0.09
# |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= 0.19
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  0.19
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Misd_0 >  0.50
# |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -0.25
# |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Drug_0 <= 0.50
# |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year <= 0.57
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- pipeline-1__Jobs_Per_Year >  0.57
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Drug_0 >  0.50
# |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_0 <= 0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_0 >  0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -0.25
# |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_1 <= 0.50
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 1.00
# |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive <= -0.20
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__DrugTests_THC_Positive >  -0.20
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  1.00
# |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.65
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.65
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest <= -0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- pipeline-1__Avg_Days_per_DrugTest >  -0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Misd_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- pipeline-2__Prior_Arrest_Episodes_Felony_1 >  0.50
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed <= 1.19
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- pipeline-1__Percent_Days_Employed >  1.19
# |   |   |   |   |   |   |   |--- class: No
# |   |   |--- pipeline-2__Gang_Affiliated_Yes >  0.50
# |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_0 <= 0.50
# |   |   |   |   |--- pipeline-1__Residence_PUMA <= -0.54
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-1__Residence_PUMA >  -0.54
# |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_0 <= 0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-2__Delinquency_Reports_0 >  0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Prop_0 >  0.50
# |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First <= -0.02
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- pipeline-1__Supervision_Risk_Score_First >  -0.02
# |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Drug_0 <= 0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- pipeline-2__Prior_Conviction_Episodes_Drug_0 >  0.50
# |   |   |   |   |   |   |--- class: Yes

# %% [markdown]
# When it is not possible to interpret a decision tree because of its complex structure, we can still extract other information from it that will help us understand the features' importance in the decision. The code in the cell below extracts the feature importances from the model (line 3), then uses this information to create a bar plot of features sorted by importance. The feature importance extracted this way is based on [Gini Importance](https://www.codecademy.com/article/fe-feature-importance-final) (as it is done in the original paper), which reflects how the features were picked when building the decision tree.

# %%
import seaborn as sns

feature_importances = tree_model.named_steps["dt"].feature_importances_

# Sort the feature importances from greatest to least using the sorted indices
sorted_indices = feature_importances.argsort()[::-1]
sorted_feature_names = tree_model.named_steps['ct'].get_feature_names_out()[sorted_indices[0:20]] # Output limited to top 20 features
sorted_importances = feature_importances[sorted_indices[0:20]]

# # Create a bar plot of the feature importances
sns.set(rc={'figure.figsize':(11.7,30)})
sns.barplot(x=sorted_importances, y=sorted_feature_names)
# Out:
# <Axes: >

# %% [markdown]
# Comment on the features importance of the tree model, compared to those seen in the logistic regression model, as well as the original paper results. Also, **what is a big limitation of using feature importance, compared to observing the coefficient of the logistic regression model?**

# %% [markdown]
# ### Question 13
#
# As before, we are interested in evaluating how the model classifies a particular sample. Let's start looking at the classification for our `hard_sample`. Is it correct?

# %%
tree_model.predict(hard_sample)
# Out:
# array(['Yes'], dtype=object)

# %% [markdown]
# We would like to be able to tell what sequence of rules has led to this final decision, but, for a tree this large, this can be difficult, unless we want to manually sift through the list of rules or write some elaborate custom code. In the next sections, we will see an alternative method (SHAP) to achieve this result.

# %% [markdown]
# ### Question 11: Evaluation of Non-inherently Interpretable Models Using a Surrogate Model
#
# Models that are not inherently interpretable ("black box" models) can still be examined to understand how they used the available features to make their predictions. In fact, there are many strategies to do this. The first one we are going to see is through use of a **surrogate model.** In this case, we train another model - an inherently interpretable one, such as a logistic regressor - on the *predictions* of the black box model, and then we try to interpret *its parameters*. Let's complete the code below to do that on the 3 non-inherently interpretable models included in this exercise: Random Forest and XGBoost.

# %% [markdown]
# #### Surrogate for Random Forest Model

# %%
# Step 1: create logistic regressor object.
# For simplicity, we will use the already existing "NIJ_logreg.joblib" and re-train it, instead of creating
# a new one. The reason for this decision is that NIJ_logreg.joblib already knows how to handle the features
# of this dataset, while a new one will need to be designed to do so.

surrogate_model_rf = joblib.load("models_for_A3/NIJ_logreg.joblib")

# Step 2: train model on random forest predictions on the training set
y_pred_rf_train = rf_model.predict(X_train)
surrogate_model_rf.fit(X_train, y_pred_rf_train)

# Step 3: visualize weights of surrogate model, as we did for the original logistic regression model
eli5.explain_weights(surrogate_model_rf[-1], feature_names=surrogate_model_rf[:-1].get_feature_names_out())
# Out:
# Explanation(estimator="LogisticRegression(C=np.float64(2.031835829826598), class_weight='balanced',\n                   max_iter=1000)", description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target='Yes', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='pipeline-2__Age_at_Release_18-22', weight=np.float64(1.0840364569833034), std=None, value=None), FeatureWeight(feature='pipeline-2__Gang_Affiliated_Yes', weight=np.float64(0.9366244519577164), std=None, value=None), FeatureWeight(feature='pipeline-2__Delinquency_Reports_1', weight=np.float64(0.7158681632008675), std=None, value=None), FeatureWeight(feature='pipeline-2__Prior_Arrest_Episodes_Felony_10 or more', weight=np.float64(0.640154352111238), std=None, value=None), FeatureWeight(feature='pipeline-2__Age_at_Release_23-27', weight=np.float64(0.5749217402152785), std=None, value=None), FeatureWeight(feature='pipeline-2__Prior_Arrest_Episodes_Misd_6 or more', weight=np.float64(0.4554828639871207), std=None, value=None), FeatureWeight(feature='pipeline-2__Gender_M', weight=np.float64(0.4409626376562075), std=None, value=None), FeatureWeight(feature='pipeline-2__Prior_Revocations_Parole_Yes', weight=np.float64(0.40483543457264165), std=None, value=None), FeatureWeight(feature='pipeline-2__Violations_ElectronicMonitoring_Yes', weight=np.float64(0.3875680651132207), std=None, value=None), FeatureWeight(feature='pipeline-2__Condition_MH_SA_Yes', weight=np.float64(0.3645257603068453), std=None, value=None)], neg=[FeatureWeight(feature='pipeline-1__Percent_Days_Employed', weight=np.float64(-0.9285540915940416), std=None, value=None), FeatureWeight(feature='pipeline-2__Age_at_Release_48 or older', weight=np.float64(-0.9110190602280228), std=None, value=None), FeatureWeight(feature='pipeline-2__Prior_Arrest_Episodes_Felony_1', weight=np.float64(-0.7496681049567433), std=None, value=None), FeatureWeight(feature='pipeline-2__Delinquency_Reports_4 or more', weight=np.float64(-0.6613115091390326), std=None, value=None), FeatureWeight(feature='pipeline-2__Age_at_Release_43-47', weight=np.float64(-0.519299810773632), std=None, value=None), FeatureWeight(feature='pipeline-2__Prior_Arrest_Episodes_Felony_2', weight=np.float64(-0.49784643161865877), std=None, value=None), FeatureWeight(feature='pipeline-2__Program_Attendances_10 or more', weight=np.float64(-0.38910742392968284), std=None, value=None), FeatureWeight(feature='pipeline-2__Prior_Arrest_Episodes_Misd_0', weight=np.float64(-0.37060598441829495), std=None, value=None), FeatureWeight(feature='pipeline-2__Age_at_Release_38-42', weight=np.float64(-0.36297194524374854), std=None, value=None), FeatureWeight(feature='pipeline-2__Delinquency_Reports_3', weight=np.float64(-0.34943642339685105), std=None, value=None)], pos_remaining=np.int64(45), neg_remaining=np.int64(60)), proba=None, score=None, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# Now that we have the weights of the surrogate model, what can we say about how the Random Forest model makes its predictions? What features seem more important? Are they similar to what we have seen for the other models so far?

# %% [markdown]
# **Note:** using a surrogate model is not always a very good strategy, because the simpler "white box" model is often unable to replicate the behavior of the most complex "black box" model. We can get a sense of how close the surrogate is approximating the original model by looking at the R<sup>2</sup> score. In the paper, they do so when trying to create a surrogate for XGBoost, and they explain:
#
# *The R<sup>2</sup> value between the XGBoost predictions and the surrogate model predictions on the test set is 0.38. The surrogate model only explains 38% of the variance in the XGBoost model’s predictions*
#
# Test this for the random forest surrogate model. How much variance is it able to capture?
#
# **Hints:**
# - Think carefully about what constitues the array of predictions and the array of ground truths in this case
# - You may remember that R<sup>2</sup> is, in fact, a metric for regression, not for classification! How can we use R<sup>2</sup> in this case? There are various ways to approximate R<sup>2</sup> for classification, as explained [here](https://datascience.oneoffcoder.com/psuedo-r-squared-logistic-regression.html). We will use the simplest one and use **count R<sup>2</sup>**, which is simply the accuracy of the surrogate classifier

# %%
# from sklearn.metrics import r2_score
# surrogate_pred = surrogate_model_rf.predict(X_train)

# compute count R2 
from sklearn.metrics import accuracy_score
surrogate_pred = surrogate_model_rf.predict(X_train)
r2_rf = accuracy_score(y_pred_rf_train, surrogate_pred)
print(f"Count R² for RF surrogate: {r2_rf:.3f}")
# Out:
# Count R² for RF surrogate: 0.753

# %% [markdown]
# Now, repeat the analysis through surrogate model for XGBoost. Comment on the results, including considerations on the following:
# - What seem to be the most important features?
# - How do the sets of most important features compare across models (do not forget logistic regression and decision tree in this comparison)?
# - How good are the surrogate models, in terms of capturing the variance of the original model? Are they reliable?
# - ...more thoughts of your choice...

# %% [markdown]
# #### Surrogate for XGBoost Model

# %%
# Create surrogate for XGBoost
surrogate_model_xgb = joblib.load("models_for_A3/NIJ_logreg.joblib")

# Get XGBoost predictions on training set
y_pred_xgb_train = xgboost_model.predict(X_train)

# Train surrogate
surrogate_model_xgb.fit(X_train, y_pred_xgb_train)

# View weights
eli5.explain_weights(surrogate_model_xgb[-1], feature_names=surrogate_model_xgb[:-1].get_feature_names_out())

# Calculate R²
surrogate_pred_xgb = surrogate_model_xgb.predict(X_train)
r2_xgb = accuracy_score(y_pred_xgb_train, surrogate_pred_xgb)
print(f"Count R² for XGBoost surrogate: {r2_xgb:.3f}")
# Out:
# Count R² for XGBoost surrogate: 0.858

# %% [markdown]
# ### Question 12: Evaluation of Non-inherently Interpretable Models Using Permutation Feature Importance
#
# Another method used to interpret black box models is using feature permutation, which means changing the value of a feature and observing changes in the model's prediction error. More important features, when changed, will result in more frequent mistakes.
#
# Luckily for us, Permutation Feature Importance already exists as a function in Scikit-Learn! All you have to do it is looking at the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.inspection.permutation_importance.html) to learn how it works, and apply it to the 3 non-inherently interpretable models of this exercise. Let's start with Random Forest.

# %% [markdown]
# #### Random Forest Model:

# %%
# Use permutation_importance on the random forest model, and save the result in a variable called "out"
out = permutation_importance(rf_model, X_test, y_test, random_state=0)

# %% [markdown]
# After you are done, you can run the cell below to visualize the top 5 most important features in a bar chart. If you like, you can change the number of features shown or try other visualization methods.

# %%
result = pd.DataFrame({"Name": X_test.columns, "Importance": out["importances_mean"], "STD": out["importances_std"]})
result = result.sort_values(by=['Importance'], ascending=False)

sns.set(rc={'figure.figsize':(11.7,7)})
sns.barplot(data=result[:5], y="Name", x="Importance")
# Out:
# <Axes: xlabel='Importance', ylabel='Name'>

# %% [markdown]
# Now, use Permutation Feature Importance on XGBoost.
#
# **Hint:** these are more complex models; if you find that this task is taking too long, you may consider reducing the number of permutations using the parameter `n_repeats`. Be aware that this produces more variable results.

# %% [markdown]
# #### XGBoost Model:

# %%
# Your solution here
# Create surrogate for XGBoost
surrogate_model_xgb = joblib.load("models_for_A3/NIJ_logreg.joblib")

# Get XGBoost predictions on training set
y_pred_xgb_train = xgboost_model.predict(X_train)

# Train surrogate
surrogate_model_xgb.fit(X_train, y_pred_xgb_train)

# View weights
eli5.explain_weights(surrogate_model_xgb[-1], feature_names=surrogate_model_xgb[:-1].get_feature_names_out())

# Calculate R²
surrogate_pred_xgb = surrogate_model_xgb.predict(X_train)
r2_xgb = accuracy_score(y_pred_xgb_train, surrogate_pred_xgb)
print(f"Count R² for XGBoost surrogate: {r2_xgb:.3f}")
# Out:
# Count R² for XGBoost surrogate: 0.858

# %% [markdown]
# Now that you have completed your analysis of feature importance using permutation, comment on the results. How do the sets of most important features compare with each other? Are this results similar to what you observed using the surrogate model?

# %% [markdown]
# ### Question 13: Evaluation of Non-inherently Interpretable Models Using SHAP
#
# The last method we are going to use to interpret the impact of each feature in our model is called SHAP, which stands for SHapley Additive exPlanations. How SHAP works is beyond the scope of this course, but if you are curious you can read the [original paper](https://arxiv.org/pdf/1705.07874.pdf) by Lundberg and Lee and check out [Lundberg's GitHub repo](https://github.com/shap/shap), which provides details on the implementation and examples.
#
# You will need to install SHAP to be able to use it:
# ```
# pip install shap
# or
# conda install -c conda-forge shap
# ```
#
# Then, import it:

# %%
pip install numpy==1.23
# Out:
# Collecting numpy==1.23
#   Using cached numpy-1.23.0-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Using cached numpy-1.23.0-cp310-cp310-win_amd64.whl (14.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.23.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\athen\anaconda3\envs\dsci430\Lib\site-packages\~~mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\athen\anaconda3\envs\dsci430\Lib\site-packages\~~mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fairlearn 0.13.0 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# pycanon 1.1.0 requires numpy==2.0.2, but you have numpy 1.23.0 which is incompatible.
# tensorflow 2.20.0 requires numpy>=1.26.0, but you have numpy 1.23.0 which is incompatible.
# ydata-profiling 0.0.dev0 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.8 which is incompatible.

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (0.49.1)
# Requirement already satisfied: numpy in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (1.23.0)
# Requirement already satisfied: scipy in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (1.7.2)
# Requirement already satisfied: pandas in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (2.3.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: colorama in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athen\anaconda3\envs\dsci430\lib\site-packages (from scikit-learn->shap) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap # may require to downgrade numpy to version = 1.23
shap.initjs()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 import shap # may require to downgrade numpy to version = 1.23
#       2 shap.initjs()
#
# File c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\shap\__init__.py:1
# ----> 1 from ._explanation import Cohorts, Explanation
#       3 # explainers
#       4 from .explainers import other
#
# File c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\shap\_explanation.py:16
#      13 import sklearn
#      14 from slicer import Alias, Obj, Slicer
# ---> 16 from .utils._clustering import hclust_ordering
#      17 from .utils._exceptions import DimensionError
#      18 from .utils._general import OpChain
#
# File c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\shap\utils\__init__.py:1
# ----> 1 from ._clustering import (
#       2     delta_minimization_order,
#       3     hclust,
#       4     hclust_ordering,
#       5     partition_tree,
#       6     partition_tree_shuffle,
#       7 )
#       8 from ._general import (
#       9     OpChain,
#      10     approximate_interactions,
#    (...)
#      20     suppress_stderr,
#      21 )
#      22 from ._masked_model import MaskedModel, make_masks
#
# File c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\shap\utils\_clustering.py:12
#      10 import scipy.spatial
#      11 import sklearn
# ---> 12 from numba import njit
#      14 from ..utils._exceptions import DimensionError
#      15 from ._show_progress import show_progress
#
# File c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\numba\__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File c:\Users\athen\anaconda3\envs\dsci430\lib\site-packages\numba\__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 0):
#      43     msg = (f"Numba needs NumPy 2.0 or less. Got NumPy "
#      44            f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.0 or less. Got NumPy 2.2.

# %% [markdown]
# SHAP needs the model (we will start with Random Forest) and samples to use to explain the predictions. For this, we will need to give it transformed samples (scaled and imputed, as required by the model) from  `X_train` or `X_test`.

# %%
X_train_enc = pd.DataFrame(
    data=rf_model.named_steps['ct'].transform(X_train),
    columns=feature_names,
    index=X_train.index,
)

X_test_enc = pd.DataFrame(
    data=rf_model.named_steps['ct'].transform(X_test),
    columns=feature_names,
    index=X_test.index,
)

ind = np.random.choice(len(X_test_enc) - 1, 1000)  
# This line just gives 1000 random indexes from the training set
# We do this because getting SHAP values for all samples would be a bit too long, but you 
# are free to try it out!

ind = np.append(ind, 5) # adding the hard sample - we'll need this later

# %% [markdown]
# The following lines are all that's needed to explain the model's predictions for a set of samples:

# %%
rf_explainer = shap.TreeExplainer(rf_model[-1])  # creating SHAP Explainer based on the model

rf_shap_values = rf_explainer.shap_values(X_test_enc.iloc[ind])  # explaining predictions for 1000 random samples

# %% [markdown]
# This gives us the SHAP values for each sample and each feature (values for the positive class):

# %%
rf_shap_values[:,:,1]

# %% [markdown]
# This is hardly interpretable, though. It is better to get the average values for each feature, which returns something similar to feature importance:

# %%
values = np.abs(rf_shap_values[:,:,1]).mean(0)
pd.DataFrame(data=values, index=feature_names, columns=["SHAP"]).sort_values(
    by="SHAP", ascending=False
)[:10]

# %% [markdown]
# The SHAP library also has a lot of ways to visualize and interpret the SHAP values - try it out!

# %%
shap_figure = shap.summary_plot(rf_shap_values[:, :, 1], X_test_enc.iloc[ind], plot_size=[12,6])

# %% [markdown]
# Given the new information obtained using the SHAP library on the Random Forest model, explain the results (you will need to refer to the SHAP documentation - or ask us for help interpreting the plots) and comment on the difference between these results and those obtained using the other methods.

# %% [markdown]
# Next, **repeat this analysis for XGBoost.**

# %%
# Your solution here

# %% [markdown]
# ### Question 14: Explaining individual predictions using SHAP
#
# Another powerful feature of SHAP is that it allows us to explain the impact of each feature on individual predictions. For example, we will be able to explain how the prediction for our hard sample was generated. Let's start by looking at the prediction for this sample given by the random forest model. **Is it correct?**

# %%
rf_model.predict(hard_sample)

# %% [markdown]
# Let's look at the **force plot** for this particular prediction, by running the cell below:

# %%
shap.force_plot(
    rf_explainer.expected_value[1],
    rf_shap_values[:,:,1][-1],
    X_test_enc.iloc[ind[-1]],
    matplotlib=True,
)

# %% [markdown]
# **Interpret the plot results,**, including the following:
# - What contributed the most to the prediction?
# - What countered the prediction the most?
# - Can we tell, by looking at the plot, that this was a difficult prediction?

# %% [markdown]
# Finally, **repeat the analysis and comment on the results of the individual predictions made on the hard sample by XGBoost and Decision Tree** (since we were not able to do the latter earlier).

# %%
# Your answer here

# %% [markdown]
# # Part 5: Final Evaluation:

# %% [markdown]
# ### Question 15
#
# Using **all the results collected so far** on accuracy, fairness and transparency of the 5 model, write your recommendation about what model, in your opinion, should be employed for this application (300 words max).

# %% [markdown]
# # Final thoughts
#
# 1) If you have completed this assignment in a group, please write a detailed description of how you divided the work and how you helped each other completing it:

# %% [markdown]
# 2) Have you used ChatGPT or a similar Large Language Model (LLM) to complete this homework? Please describe how you used the tool. We will never deduct points for using LLMs for completing homework assignments, but this helps us understand how you are using the tool and advise you in case we believe you are using it incorrectly.

# %% [markdown]
# 3) Have you struggled with some parts (or all) of this homework? Do you have pending questions you would like to ask? Write them down here!
